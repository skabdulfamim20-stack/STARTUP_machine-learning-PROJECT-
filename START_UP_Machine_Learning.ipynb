# %% [markdown]
# <a href="https://colab.research.google.com/github/skabdulfamim20-stack/STARTUP_machine-learning-PROJECT-/blob/main/START_UP_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/Indian_Startup_Funding_Dataset.csv')

# %%
df
# Out:
#      Startup_ID Startup_Name       Industry       City        State  \
# 0             1  Startup_001  Cybersecurity       Pune  Maharashtra
# 1             2  Startup_002     E-commerce       Pune  Maharashtra
# 2             3  Startup_003       AgriTech  Ahmedabad      Gujarat
# 3             4  Startup_004         EdTech  Hyderabad    Telangana
# 4             5  Startup_005         EdTech     Jaipur    Rajasthan
# ..          ...          ...            ...        ...          ...
# 295         296  Startup_296           SaaS     Jaipur    Rajasthan
# 296         297  Startup_297  Cybersecurity  Bengaluru    Karnataka
# 297         298  Startup_298        FinTech    Kolkata  West Bengal
# 298         299  Startup_299        FinTech    Kolkata  West Bengal
# 299         300  Startup_300             AI    Kolkata  West Bengal
#
#      Funding_Year Funding_Stage    Lead_Investor  Funding_Amount_USD  \
# 0            2025      Series A   Blume Ventures            20300000
# ...

# %%
df.head(5)
# Out:
#    Startup_ID Startup_Name       Industry       City        State  \
# 0           1  Startup_001  Cybersecurity       Pune  Maharashtra
# 1           2  Startup_002     E-commerce       Pune  Maharashtra
# 2           3  Startup_003       AgriTech  Ahmedabad      Gujarat
# 3           4  Startup_004         EdTech  Hyderabad    Telangana
# 4           5  Startup_005         EdTech     Jaipur    Rajasthan
#
#    Funding_Year Funding_Stage   Lead_Investor  Funding_Amount_USD  Employees  \
# 0          2025      Series A  Blume Ventures            20300000        417
# 1          2025  Pre-Series A           Accel            12200000        406
# 2          2022          Seed           Accel             8300000        362
# 3          2025      Series C         Peak XV            43800000        393
# 4          2018  Pre-Series A  Blume Ventures            36800000        476
#
#    Status
# 0  Active
# 1  Active
# 2  Active
# 3  Active
# 4  Active

# %%
df.tail(5)
# Out:
#      Startup_ID Startup_Name       Industry       City        State  \
# 295         296  Startup_296           SaaS     Jaipur    Rajasthan
# 296         297  Startup_297  Cybersecurity  Bengaluru    Karnataka
# 297         298  Startup_298        FinTech    Kolkata  West Bengal
# 298         299  Startup_299        FinTech    Kolkata  West Bengal
# 299         300  Startup_300             AI    Kolkata  West Bengal
#
#      Funding_Year Funding_Stage    Lead_Investor  Funding_Amount_USD  \
# 295          2024      Series B     Tiger Global            47800000
# 296          2024      Series A            Accel            34000000
# 297          2022  Pre-Series A  Matrix Partners            31800000
# 298          2022      Series B  Sequoia Capital            10500000
# 299          2022      Series A  Matrix Partners            13200000
#
#      Employees  Status
# 295         41  Active
# 296        390  Active
# 297        200  Active
# 298        185  Active
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Startup_ID          300 non-null    int64
#  1   Startup_Name        300 non-null    object
#  2   Industry            300 non-null    object
#  3   City                300 non-null    object
#  4   State               300 non-null    object
#  5   Funding_Year        300 non-null    int64
#  6   Funding_Stage       300 non-null    object
#  7   Lead_Investor       300 non-null    object
#  8   Funding_Amount_USD  300 non-null    int64
#  9   Employees           300 non-null    int64
#  10  Status              300 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 25.9+ KB

# %%
print(df.shape)
# Out:
# (300, 11)

# %%
df.isnull().sum()
# Out:
# Startup_ID            0
# Startup_Name          0
# Industry              0
# City                  0
# State                 0
# Funding_Year          0
# Funding_Stage         0
# Lead_Investor         0
# Funding_Amount_USD    0
# Employees             0
# Status                0
# dtype: int64

# %%
df.describe()
# Out:
#        Startup_ID  Funding_Year  Funding_Amount_USD   Employees
# count  300.000000    300.000000        3.000000e+02  300.000000
# mean   150.500000   2021.976667        2.474900e+07  250.030000
# std     86.746758      2.592010        1.471352e+07  144.001588
# min      1.000000   2018.000000        1.000000e+05    6.000000
# 25%     75.750000   2020.000000        1.190000e+07  129.000000
# 50%    150.500000   2022.000000        2.470000e+07  240.000000
# 75%    225.250000   2024.000000        3.800000e+07  375.750000
# max    300.000000   2026.000000        4.950000e+07  500.000000

# %%
df.describe(include="all")
# Out:
#         Startup_ID Startup_Name Industry       City        State  \
# count   300.000000          300      300        300          300
# unique         NaN          300       10         10            9
# top            NaN  Startup_300   EdTech  Ahmedabad  Maharashtra
# freq           NaN            1       40         40           51
# mean    150.500000          NaN      NaN        NaN          NaN
# std      86.746758          NaN      NaN        NaN          NaN
# min       1.000000          NaN      NaN        NaN          NaN
# 25%      75.750000          NaN      NaN        NaN          NaN
# 50%     150.500000          NaN      NaN        NaN          NaN
# 75%     225.250000          NaN      NaN        NaN          NaN
# max     300.000000          NaN      NaN        NaN          NaN
#
#         Funding_Year Funding_Stage    Lead_Investor  Funding_Amount_USD  \
# count     300.000000           300              300        3.000000e+02
# ...

# %%
import matplotlib.pyplot as plt

# %%
df['Industry'].value_counts().plot(kind='bar',figsize=(10,5))
plt.xlabel('Industry')
plt.ylabel('Count')
plt.title('Industry Distribution')
plt.show()

# %%
df['Funding_Stage'].value_counts().plot(kind='bar',figsize=(10,5))
plt.xlabel('Funding_Stage')
plt.ylabel('Count')
plt.title('Funding_Stage Distribution')
plt.show()

# %%
df['City'].value_counts().plot(kind='bar',figsize=(10,5))
plt.xlabel('City')
plt.ylabel('Count')
plt.title('City Distribution')
plt.show()

# %%
df['State'].value_counts().plot(kind='bar',figsize=(10,5))
plt.xlabel('State')
plt.ylabel('Count')
plt.title('State Distribution')
plt.show()

# %%
df['Lead_Investor'].value_counts().plot(kind='bar',figsize=(10,5))
plt.xlabel('Lead_Investor')
plt.ylabel('Count')
plt.title('Lead_Investor Distribution')
plt.show()

# %%
df.groupby('Funding_Year')['Funding_Amount_USD'].sum().plot(kind='bar',figsize=(10,5))
plt.title('Funding_Year')
plt.show()

# %%
df['Employees'].plot(kind='hist',bins=20, figsize=(10,5))
plt.title('Distribution of Employees')
plt.xlabel('Employees')
plt.ylabel('Frequency')
plt.show()

# %%
print(df.columns)
# Out:
# Index(['Startup_ID', 'Startup_Name', 'Industry', 'City', 'State',
#        'Funding_Year', 'Funding_Stage', 'Lead_Investor', 'Funding_Amount_USD',
#        'Employees', 'Status'],
#       dtype='object')

# %%
x = df.drop('Funding_Amount_USD', axis=1)
y = df['Funding_Amount_USD']

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
for column in x.select_dtypes(include=['object']).columns:
    x[column] = encoder.fit_transform(x[column])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(random_state=42)
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test,predictions)
print(f"Accuracy: {accuracy}:.2f")
# Out:
# Accuracy: 0.0:.2f
